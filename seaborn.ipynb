# %% [markdown]
# # <font color="yellow"> SIRISHA DUDDUKUNTA</font>

# %% [markdown]
# # <font color="darkpink">SEABORN</font>

# %% [markdown]
# - Used for data visualzation & based on Matplotlib
# - Seaborn allows the creation of stastical graphs

# %% [markdown]
# ## Functionalities:
# - Allows comparison between multiple variables
# - Supports multi-plot grids
# - Available univariate and bivariate visualizations
# - Availability of different color palettes
# - Estimates and plots linear regression automatically

# %% [markdown]
# ## python seaborn functions
#
#  ### visualizing stastical relationships
#  - process of understanding relationships between variables of a dataset
# ### plotting with categorical data
#  - Main variable is further divided into discrete groups
# ### visualizing the distribution of a dataset
#  - understanding datasets with content to being univariate or bivariate

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## import data

# %%
data=pd.read_csv("C:\\Users\\siris\\OneDrive\\Desktop\\New folder\iris.csv")
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Distribution Plots

# %% [markdown]
# ## Distribution Plot

# %%
sns.distplot(data["sepal.length"])

# %%
sns.distplot(data["sepal.length"],kde=False)

# %%
sns.distplot(data["sepal.length"],kde=False, bins=25)

# %% [markdown]
# ## Joint plot

# %%
sns.jointplot(x="sepal.length", y="petal.length",data=data,kind="reg")

# %%
sns.jointplot(x="sepal.length", y="petal.length",data=data,kind="kde")

# %%
sns.jointplot(x="sepal.length", y="petal.length",data=data,kind="hex")

# %% [markdown]
# # KDE Plot

# %%
sns.kdeplot(data['sepal.width'])

# %% [markdown]
# # Pair Plots

# %%
sns.pairplot(data)

# %%
emp=pd.read_csv("C:\\Users\\siris\\OneDrive\\Desktop\\New folder\employees.csv")
emp
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %% [markdown]
# # Rug Plot

# %%
sns.rugplot(data['petal.length'])

# %% [markdown]
# # styling

# %%
sns.set_style('ticks')

plt.figure(figsize=(0,4))

sns.jointplot(x="sepal.length", y="petal.length",data=data,kind="reg")

# %%
sns.set_style('darkgrid')

plt.figure(figsize=(0,4))

sns.jointplot(x="sepal.length", y="petal.length",data=data,kind="reg")

# %%
sns.set_style('whitegrid')

plt.figure(figsize=(0,4))

sns.jointplot(x="sepal.length", y="petal.length",data=data,kind="reg")

# %%
sns.set_style('white')

plt.figure(figsize=(0,4))

sns.set_context('paper',font_scale=1.4)

sns.jointplot(x="sepal.length", y="petal.length",data=data,kind="reg")

# %%
sns.set_style('white')

plt.figure(figsize=(0,4))

sns.set_context('talk',font_scale=1.4)

sns.jointplot(x="sepal.length", y="petal.length",data=data,kind="reg")

# %%
sns.set_style('white')

plt.figure(figsize=(0,4))

sns.set_context('paper',font_scale=1.4)

sns.jointplot(x="sepal.length", y="petal.length",data=data,kind="reg")

sns.despine(left=False)

# %%
sns.set_style('white')

plt.figure(figsize=(0,4))

sns.set_context('paper',font_scale=1.4)

sns.jointplot(x="sepal.length", y="petal.length",data=data,kind="reg")

sns.despine(left=True)

# %%
sns.set_style('white')

plt.figure(figsize=(0,4))

sns.set_context('paper',font_scale=1.4)

sns.jointplot(x="sepal.length", y="petal.length",data=data,kind="reg")

sns.despine(left=True,bottom=True)

# %% [markdown]
# # Categorical Plots

# %% [markdown]
# ## Bar plots

# %%
sns.barplot(x="sepal.width",y="petal.width",data=data)

# %%
sns.barplot(x="sepal.width",y="petal.width",data=data,estimator=np.var)

# %%
sns.barplot(x="sepal.width",y="petal.width",data=data,estimator=np.median)

# %%
sns.barplot(x="sepal.width",y="petal.width",data=data,estimator=np.mean)

# %%
sns.barplot(x="sepal.width",y="petal.width",data=data,estimator=np.std)

# %% [markdown]
# # Count Plot

# %%
sns.countplot(x="sepal.width",data=data)

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(x="sepal.width",y="petal.width",data=data,hue="sepal.length")

# %% [markdown]
# # violin plot

# %%
sns.violinplot(x="sepal.width",y="petal.width",data=data)

# %% [markdown]
# # Strip Plot

# %%
plt.figure(figsize=(8,5))
sns.stripplot(x="sepal.width",y="petal.width",data=data)

# %%
plt.figure(figsize=(8,5))
sns.stripplot(x="Salary",y="Gender",data=emp)

# %% [markdown]
# # Swarm Plot

# %%
sns.violinplot(x="Salary",y="Gender",data=emp)
sns.swarmplot(x="Salary",y="Gender",data=emp, color="white")

# %%
sns.violinplot(x="Salary",y="Gender",data=emp)
sns.swarmplot(x="Salary",y="Gender",data=emp)

# %% [markdown]
# # MATRIX PLOTS

# %% [markdown]
# # Heat Maps

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper',font_scale =1.4)

data_mx=data.corr()


sns.heatmap(data_mx,annot=True,cmap="Blues")

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper',font_scale =1.4)

emp_mx=emp.corr()


sns.heatmap(emp_mx,annot=True,cmap="Blues")

# %% [markdown]
# # Cluster Map

# %%
data=pd.read_csv("C:\\Users\\siris\\OneDrive\\Desktop\\New folder\iris.csv")



species=data.pop("variety")
sns.clustermap(data)

# %%
emm=pd.read_csv("C:\\Users\\siris\\OneDrive\\Desktop\\New folder\employees.csv")
emm
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %% [markdown]
# # PairGrid

# %%
data_g=sns.PairGrid(data)
data_g.map(plt.scatter)

# %%
data_g=sns.PairGrid(data)
data_g.map(plt.scatter)
data_g.map_diag(plt.hist)

# %%
data_g=sns.PairGrid(data)
data_g.map(plt.scatter)
data_g.map_diag(plt.hist)

data_g.map_offdiag(plt.scatter)

# %% [markdown]
# # Facet grid

# %%
data_fg=sns.FacetGrid(data,col="petal.length",row="petal.width")
